# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthkumar777/Movie-Recommendation-using-Sentiment-Analysis/blob/main/Data_preprocessing_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# #Extracting features of 2020 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# <ipython-input-8-29c6c5e572fc>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# ...

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [276 rows x 2 columns]

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '091bbb8bfeb661832410a654d3e88bc7'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " "
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [276 rows x 2 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# <ipython-input-17-bc52fe9b0c35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# <ipython-input-19-42c5f763f942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))
# Out:
# <ipython-input-21-ca9c918a7840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))
# Out:
# <ipython-input-23-db7926ce943c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# ...

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','movie_title']]

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272   Paul Greengrass              Tom Hanks      Helena Zengel
# 273       Regina King      Kingsley Ben-Adir          Eli Goree
# 274   Emerald Fennell         Carey Mulligan         Bo Burnham
# 275  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name            movie_title
# 0           John Cho             The Grudge
# 1    Jessica Henwick             Underwater
# 2        Salma Hayek            Like a Boss
# ...

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      5
# actor_3_name     28
# movie_title       0
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# movie_title      0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# <ipython-input-31-83e83e91073b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 270       Pete Docter             Jamie Foxx           Tina Fey
# 271  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 273       Regina King      Kingsley Ben-Adir          Eli Goree
# 274   Emerald Fennell         Carey Mulligan         Bo Burnham
# 275  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name            movie_title
# 0           John Cho             the grudge
# 1    Jessica Henwick             underwater
# 2        Salma Hayek            like a boss
# ...

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#                       director_name       actor_1_name          actor_2_name  \
# 0    Joachim Rønning Espen Sandberg        Johnny Depp         Javier Bardem
# 1                       Zack Snyder        Ben Affleck          Henry Cavill
# 2                     Taika Waititi    Chris Hemsworth        Tom Hiddleston
# 3                        James Gunn        Chris Pratt           Zoe Saldana
# 4                     Sean McNamara     Pierce Brosnan          William Hurt
# ..                              ...                ...                   ...
# 977          Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 978                    Greta Gerwig      Saoirse Ronan           Emma Watson
# 979                      Sam Mendes      George MacKay  Dean-Charles Chapman
# 980           Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 981                 Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)
# Out:
# <ipython-input-35-3b1e79f461dc>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#                        director_name           actor_1_name    actor_2_name  \
# 0     Joachim Rønning Espen Sandberg            Johnny Depp   Javier Bardem
# 1                        Zack Snyder            Ben Affleck    Henry Cavill
# 2                      Taika Waititi        Chris Hemsworth  Tom Hiddleston
# 3                         James Gunn            Chris Pratt     Zoe Saldana
# 4                      Sean McNamara         Pierce Brosnan    William Hurt
# ...                              ...                    ...             ...
# 1225                     Pete Docter             Jamie Foxx        Tina Fey
# 1226                Robert Rodriguez  Priyanka Chopra Jonas    Pedro Pascal
# 1227                     Regina King      Kingsley Ben-Adir       Eli Goree
# 1228                 Emerald Fennell         Carey Mulligan      Bo Burnham
# 1229                Kornél Mundruczó          Vanessa Kirby    Shia LaBeouf
#
# ...

# %%
final_df.to_csv('main_data.csv',index=False)
